# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 $('div.output_stderr').hide();
 } else {
 $('div.input').show();
 $('div.output_stderr').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action='javascript:code_toggle()'><input STYLE='color: #4286f4' type='submit' value='Click here to toggle on/off the raw code.'></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  $('div.output_stderr').hide();
#  } else {
#  $('div.input').show();
#  $('div.output_stderr').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action='javascript:code_toggle()'><input STYLE='color: #4286f4' type='submit' value='Click here to toggle on/off the raw code.'></form>

# %%
from itertools import combinations
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import xarray as xr

import warnings
warnings.filterwarnings('ignore', 'numpy equal will not check object identity in the future')

from src.plotting import plot_connectivity

path = '../Processed-Data/HPc_*.nc'
brain_areas = ['CA1', 'iCA1', 'PFC']

# %% [markdown]
# ## All Ripples - HPc

# %% [markdown]
# ### Low Frequencies

# %%
covariate = 'all_ripples'
level1 = ''
level2 = None
resolution = '4Hz_Resolution'
frequency = slice(0, 30)

for brain_area_pair in combinations(brain_areas, 2):
    plot_connectivity(
        path, brain_area_pair, frequency, resolution, covariate,
        level1, level2=level2, figsize=(15, 10), connectivity_measure='coherence_magnitude')

# %% [markdown]
# ### Gamma Frequencies
#
# #### 4 Hz Frequency Resolution

# %%
resolution = '4Hz_Resolution'
frequency = slice(20, 125)
for brain_area_pair in combinations(brain_areas, 2):
    plot_connectivity(
        path, brain_area_pair, frequency, resolution, covariate,
        level1, level2=level2, figsize=(15, 10), connectivity_measure='coherence_magnitude')

# %% [markdown]
# #### 10 Hz Frequency Resolution

# %%
resolution = '10Hz_Resolution'
for brain_area_pair in combinations(brain_areas, 2):
    plot_connectivity(
        path, brain_area_pair, frequency, resolution, covariate,
        level1, level2=level2, figsize=(15, 10), connectivity_measure='coherence_magnitude')

# %% [markdown]
# ### Ripple Frequencies

# %%
frequency = slice(100, 300)
resolution = '20Hz_Resolution'
for brain_area_pair in combinations(brain_areas, 2):
    plot_connectivity(
        path, brain_area_pair, frequency, resolution, covariate,
        level1, level2=level2, figsize=(15, 10), connectivity_measure='coherence_magnitude')

# %% [markdown]
# ## Ripple Direction: Forward vs. Reverse
#
# ### Low Frequencies

# %%
covariate = 'ripple_direction'
level1 = 'forward'
level2 = 'reverse'
resolution = '4Hz_Resolution'
frequency = slice(0, 30)

for brain_area_pair in combinations(brain_areas, 2):
    plot_connectivity(
        path, brain_area_pair, frequency, resolution, covariate,
        level1, level2=level2, figsize=(15, 10), connectivity_measure='coherence_magnitude')

# %% [markdown]
# ### Gamma Frequencies
#
# #### 4 Hz Frequency Resolution

# %%
resolution = '4Hz_Resolution'
frequency = slice(20, 125)

for brain_area_pair in combinations(brain_areas, 2):
    plot_connectivity(
        path, brain_area_pair, frequency, resolution, covariate,
        level1, level2=level2, figsize=(15, 10), connectivity_measure='coherence_magnitude')

# %% [markdown]
# #### 10 Hz Frequency Resolution

# %%
resolution = '10Hz_Resolution'
frequency = slice(20, 125)

for brain_area_pair in combinations(brain_areas, 2):
    plot_connectivity(
        path, brain_area_pair, frequency, resolution, covariate,
        level1, level2=level2, figsize=(15, 10), connectivity_measure='coherence_magnitude')

# %% [markdown]
# ### Ripple Frequencies

# %%
resolution = '20Hz_Resolution'
frequency = slice(100, 300)

for brain_area_pair in combinations(brain_areas, 2):
    plot_connectivity(
        path, brain_area_pair, frequency, resolution, covariate,
        level1, level2=level2, connectivity_measure='coherence_magnitude')

# %% [markdown]
# ## Ripple Trajectory: Inbound vs. Outbound
#
# ### Low Frequencies

# %%
covariate = 'ripple_trajectory'
level1 = 'inbound'
level2 = 'outbound'
resolution = '4Hz_Resolution'
frequency = slice(0, 30)

for brain_area_pair in combinations(brain_areas, 2):
    plot_connectivity(
        path, brain_area_pair, frequency, resolution, covariate,
        level1, level2=level2, connectivity_measure='coherence_magnitude')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-017f4df489e0> in <module>()
#       8     plot_connectivity(
#       9         path, brain_area_pair, frequency, resolution, covariate,
# ---> 10         level1, level2=level2, connectivity_measure='coherence_magnitude')
#
# /projectnb/braincom/Jadhav-2016-Data-Analysis/src/plotting.py in plot_connectivity(path, brain_area_pair, frequency, resolution, covariate, level1, level2, figsize, connectivity_measure)
#     112         axes[1, 0].set_title('Baseline')
#     113
# --> 114     ds_change = (ds1 - ds2).mean(DIMS)
#     115     ds_change.plot(
#     116         x='time', y='frequency', ax=axes[0, 2], cmap='PRGn', center=0)
#
# /usr3/graduate/edeno/.conda/envs/Jadhav-2016-Data-Analysis/lib/python3.5/site-packages/xarray/core/dataarray.py in func(self, other)
#    1545             if hasattr(other, 'indexes'):
#    1546                 align_type = OPTIONS['arithmetic_join'] if join is None else join
# -> 1547                 self, other = align(self, other, join=align_type, copy=False)
#    1548             other_variable = getattr(other, 'variable', other)
#    1549             other_coords = getattr(other, 'coords', None)
#
# /usr3/graduate/edeno/.conda/envs/Jadhav-2016-Data-Analysis/lib/python3.5/site-packages/xarray/core/alignment.py in align(*objects, **kwargs)
#     153                     'arguments without labels along dimension %r cannot be '
#     154                     'aligned because they have different dimension sizes: %r'
# --> 155                     % (dim, sizes))
#     156
#     157     result = []
#
# ValueError: arguments without labels along dimension 'session' cannot be aligned because they have different dimension sizes: {16, 15}

# %% [markdown]
# ### Gamma Frequencies
#
# #### 4 Hz Frequency Resolution

# %%
resolution = '4Hz_Resolution'
frequency = slice(20, 125)

for brain_area_pair in combinations(brain_areas, 2):
    plot_connectivity(
        path, brain_area_pair, frequency, resolution, covariate,
        level1, level2=level2, connectivity_measure='coherence_magnitude')

# %% [markdown]
# #### 10 Hz Frequency Resolution

# %%
resolution = '10Hz_Resolution'
frequency = slice(20, 125)

for brain_area_pair in combinations(brain_areas, 2):
    plot_connectivity(
        path, brain_area_pair, frequency, resolution, covariate,
        level1, level2=level2, connectivity_measure='coherence_magnitude')

# %% [markdown]
# ### Ripple Frequencies

# %%
resolution = '20Hz_Resolution'
frequency = slice(100, 300)

for brain_area_pair in combinations(brain_areas, 2):
    plot_connectivity(
        path, brain_area_pair, frequency, resolution, covariate,
        level1, level2=level2, connectivity_measure='coherence_magnitude')
