# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
# %qtconsole
# %precision 3
# Out:
# '%.3f'

# %%
import pandas as pd
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import logging
logging.basicConfig(level=logging.INFO)

# %%
epoch_key = ('bon', 4, 2)

# %%
from src.parameters import (ANIMALS, SAMPLING_FREQUENCY,
                            MULTITAPER_PARAMETERS, FREQUENCY_BANDS,
                            RIPPLE_COVARIATES)

# %%
from src.data_processing import (get_interpolated_position_dataframe,
                              get_LFP_dataframe,
                              get_mark_indicator_dataframe,
                              get_spike_indicator_dataframe,
                              make_neuron_dataframe,
                              make_tetrode_dataframe, reshape_to_segments,
                              save_xarray)

# %%
tetrode_info = (
    make_tetrode_dataframe(ANIMALS)
    .loc[epoch_key]
    .set_index(['animal', 'day', 'epoch', 'tetrode_number'],
               drop=False))
tetrode_info
# Out:
#                                 animal       area  day    depth descrip  \
# animal day epoch tetrode_number
# bon    4   2     1                 bon        CA3    4  [[149]]     NaN
#                  2                 bon        CA3    4  [[151]]     NaN
#                  3                 bon        CA1    4  [[100]]     NaN
#                  4                 bon        CA1    4  [[107]]     NaN
#                  5                 bon        CA1    4  [[105]]     NaN
#                  6                 bon        NaN    4    [[0]]     NaN
#                  7                 bon        CA3    4  [[162]]     NaN
#                  8                 bon        CA3    4  [[154]]     NaN
#                  9                 bon        NaN    4      NaN     NaN
#                  10                bon        CA3    4  [[146]]     NaN
#                  11                bon        CA1    4   [[96]]     NaN
#                  12                bon        CA1    4  [[136]]     NaN
# ...

# %%
mark_variables = ['channel_1_max', 'channel_2_max', 'channel_3_max',
                  'channel_4_max']
hippocampal_tetrodes = tetrode_info.loc[
    tetrode_info.area.isin(['CA1', 'iCA1', 'CA3']) &
    ~tetrode_info.descrip.str.endswith('Ref').fillna(False) &
    tetrode_info.numcells > 0]

position_info = get_interpolated_position_dataframe(epoch_key, ANIMALS)

marks = [(get_mark_indicator_dataframe(tetrode_key, ANIMALS)
          .loc[:, mark_variables])
         for tetrode_key in hippocampal_tetrodes.index]
marks = [tetrode_marks for tetrode_marks in marks
         if (tetrode_marks.loc[position_info.speed > 4, :].dropna()
             .shape[0]) != 0]

# %%
fig, ax = plt.subplots(1,1, figsize=(12, 9))

position_info.linear_position.loc[
    (position_info.trajectory_direction == 'Inbound') &
    (position_info.speed > 4)
].plot(linestyle='None', marker='.', ax=ax);

position_info.linear_position.loc[
    (position_info.trajectory_direction == 'Outbound') &
    (position_info.speed > 4)
].plot(linestyle='None', marker='.', ax=ax);

# %%
position = position_info.loc[position_info.speed > 4].loc[2500:].linear_position.values
spike_marks = np.stack([m.loc[position_info.speed > 4].loc[2500:] for m in marks], axis=0)
trajectory_direction = position_info.loc[position_info.speed > 4].loc[2500:].trajectory_direction.values

# %%
from src.ripple_decoding import ClusterlessDecoder

decoder = ClusterlessDecoder(
    position, trajectory_direction, spike_marks,
    SAMPLING_FREQUENCY,
    replay_speedup_factor=33,
    n_position_bins=61
)
decoder.fit();
# Out:
# INFO:src.ripple_decoding.decoders:Fitting state transition model...
# INFO:src.ripple_decoding.decoders:Fitting observation model...

# %%
decoder.plot_initial_conditions()

# %%
decoder.plot_state_transition_model()

# %%
state_transition = decoder.state_transition_matrix

(state_transition.sel(state='Outbound-Forward') - state_transition.sel(state='Inbound-Forward')).plot(
    x='position_t_1', y='position_t', robust=True);

# %%
decoder.plot_observation_model();

# %%
ripple_times = np.array([[2790.730, 2791.069],
                         [2570.073, 2570.246],
                         [2947.943, 2948.179],
                         [2585.179, 2585.421]])

# %%
from src.analysis import _get_ripple_marks

test_marks = _get_ripple_marks(
        marks, ripple_times, SAMPLING_FREQUENCY)

# %%
results = [decoder.predict(ripple_marks, time)
           for ripple_marks, time in test_marks]

# %%
results[0].plot_posterior_density();

# %%
results[0].plot_state_probability();

# %%
xr.DataArray(
    np.any(~np.isnan(results[0].spikes), axis=-1) * 1,
    dims=['tetrodes', 'time'],
    coords=dict(
        tetrodes=np.arange(results[0].spikes.shape[0]) + 1,
        time=np.arange(results[0].spikes.shape[1]) / SAMPLING_FREQUENCY
    )
).plot(x='time', y='tetrodes', size=7);

# %%
results[1].plot_posterior_density();

# %%
results[1].plot_state_probability();

# %%
xr.DataArray(
    np.any(~np.isnan(results[1].spikes), axis=-1) * 1,
    dims=['tetrodes', 'time'],
    coords=dict(tetrodes=np.arange(results[1].spikes.shape[0]) + 1)
).plot(x='time', y='tetrodes', size=7);

# %%
results[2].plot_posterior_density();

# %%
results[2].plot_state_probability();

# %%
xr.DataArray(
    np.any(~np.isnan(results[2].spikes), axis=-1) * 1,
    dims=['tetrode', 'time'],
    coords=dict(tetrode=np.arange(results[2].spikes.shape[0]) + 1)
).plot(x='time', y='tetrode', size=7);

# %%
results[3].plot_posterior_density();

# %%
results[3].plot_state_probability();

# %%
xr.DataArray(
    np.any(~np.isnan(results[3].spikes), axis=-1) * 1,
    dims=['tetrode', 'time'],
    coords=dict(tetrode=np.arange(results[3].spikes.shape[0]) + 1)
).plot(x='time', y='tetrode', size=7);

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 9))
for ax, r in zip(axes.ravel().tolist(), results):
    r.plot_state_probability(ax=ax);
plt.tight_layout()
