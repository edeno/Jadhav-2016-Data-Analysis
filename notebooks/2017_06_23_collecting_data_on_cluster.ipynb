# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Purpose
#
# The purpose of this notebook is to test out collecting the analysis run on the cluster, which saves an analysis file for each epoch.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import xarray as xr

# %% [markdown]
# Let's try reading in ripple-locked power for all ripples with a 4Hz frequency resolution.

# %%
from src.data_processing import read_netcdfs

combined = read_netcdfs('../Processed-Data/*.nc', dim='session',
                        group='4Hz_Resolution/all_ripples/power',
                        transform_func=None)

combined
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-20-4c91484d3564> in <module>()
#       3 combined = read_netcdfs('../Processed-Data/*.nc', dim='session',
#       4                         group='4Hz_Resolution/all_ripples/power',
# ----> 5                         transform_func=None)
#       6
#       7 combined
#
# /projectnb/braincom/Jadhav-2016-Data-Analysis/src/data_processing.py in read_netcdfs(files, dim, transform_func, group)
#     786
#     787     paths = sorted(glob(files))
# --> 788     datasets = [process_one_path(p) for p in paths]
#     789     return xr.concat(datasets, dim)
#
# /projectnb/braincom/Jadhav-2016-Data-Analysis/src/data_processing.py in <listcomp>(.0)
#     786
#     787     paths = sorted(glob(files))
# --> 788     datasets = [process_one_path(p) for p in paths]
#     789     return xr.concat(datasets, dim)
#
# /projectnb/braincom/Jadhav-2016-Data-Analysis/src/data_processing.py in process_one_path(path)
#     775     def process_one_path(path):
#     776         # use a context manager, to ensure the file gets closed after use
# --> 777         with xr.open_dataset(path, group=group, decode_cf=False) as ds:
#     778             # transform_func should do some sort of selection or
#     779             # aggregation
#
# /usr3/graduate/edeno/.conda/envs/Jadhav-2016-Data-Analysis/lib/python3.5/site-packages/xarray/backends/api.py in open_dataset(filename_or_obj, group, decode_cf, mask_and_scale, decode_times, autoclose, concat_characters, decode_coords, engine, chunks, lock, cache, drop_variables)
#     280         if engine == 'netcdf4':
#     281             store = backends.NetCDF4DataStore(filename_or_obj, group=group,
# --> 282                                               autoclose=autoclose)
#     283         elif engine == 'scipy':
#     284             store = backends.ScipyDataStore(filename_or_obj,
#
# /usr3/graduate/edeno/.conda/envs/Jadhav-2016-Data-Analysis/lib/python3.5/site-packages/xarray/backends/netCDF4_.py in __init__(self, filename, mode, format, group, writer, clobber, diskless, persist, autoclose)
#     208                                    diskless=diskless, persist=persist,
#     209                                    format=format)
# --> 210         self.ds = opener()
#     211         self._autoclose = autoclose
#     212         self._isopen = True
#
# /usr3/graduate/edeno/.conda/envs/Jadhav-2016-Data-Analysis/lib/python3.5/site-packages/xarray/backends/netCDF4_.py in _open_netcdf4_group(filename, mode, group, **kwargs)
#     183     import netCDF4 as nc4
#     184
# --> 185     ds = nc4.Dataset(filename, mode=mode, **kwargs)
#     186
#     187     with close_on_error(ds):
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__ (netCDF4/_netCDF4.c:13815)()
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success (netCDF4/_netCDF4.c:12601)()
#
# OSError: NetCDF: HDF error

# %%
from functools import partial

def select_brain_areas(dataset, area1='', area2=''):
    if 'tetrode1' in dataset.coords:
        return dataset.sel(
            tetrode1=dataset.tetrode1[dataset.brain_area1==area1],
            tetrode2=dataset.tetrode2[dataset.brain_area2==area2]
        )
    else:
        # The dataset is power
        return dataset.sel(
            tetrode=dataset.tetrode[dataset.brain_area==area1],
        )

CA1_PFC = partial(select_brain_areas, area1='CA1', area2='PFC')

combined = read_netcdfs('../Processed-Data/*.nc', dim='session',
                        group='4Hz_Resolution/all_ripples/coherence',
                        transform_func=CA1_PFC)

combined

# %%
ripple_info = pd.read_hdf('../Processed-Data/HPa_01_04.nc', key='ripple_info')
ripple_info
# Out:
#     animal  day  epoch  ripple_number ripple_trajectory ripple_direction  \
# 0      HPa    1      4              1           inbound          forward
# 1      HPa    1      4              2           inbound          reverse
# 2      HPa    1      4              3           inbound          forward
# 3      HPa    1      4              4           inbound          forward
# 4      HPa    1      4              5           inbound          reverse
# 5      HPa    1      4              6           inbound          forward
# 6      HPa    1      4              7           inbound          reverse
# 7      HPa    1      4              8          outbound          forward
# 8      HPa    1      4              9           inbound          reverse
# 9      HPa    1      4             10          outbound          reverse
# 10     HPa    1      4             11           inbound          forward
# 11     HPa    1      4             12           inbound          reverse
# 12     HPa    1      4             13           inbound          reverse
# 13     HPa    1      4             14          outbound          reverse
# 14     HPa    1      4             15           inbound          forward
# 15     HPa    1      4             16           inbound          forward
# 16     HPa    1      4             17           inbound          forward
# 17     HPa    1      4             18           inbound          reverse
# 18     HPa    1      4             19          outbound          forward
# 19     HPa    1      4             20          outbound          forward
# 20     HPa    1      4             21          outbound          reverse
# 21     HPa    1      4             22           inbound          reverse
# 22     HPa    1      4             23           inbound          forward
# 23     HPa    1      4             24          outbound          forward
# 24     HPa    1      4             25          outbound          reverse
# 25     HPa    1      4             26           inbound          reverse
# 26     HPa    1      4             27           inbound          reverse
# 27     HPa    1      4             28          outbound          forward
# 28     HPa    1      4             29          outbound          reverse
# 29     HPa    1      4             30          outbound          reverse
# ..     ...  ...    ...            ...               ...              ...
# 291    HPa    1      4            292           inbound          reverse
# 292    HPa    1      4            293           inbound          forward
# 293    HPa    1      4            294           inbound          forward
# 294    HPa    1      4            295          outbound          forward
# 295    HPa    1      4            296           inbound          reverse
# 296    HPa    1      4            297           inbound          reverse
# 297    HPa    1      4            298          outbound          reverse
# 298    HPa    1      4            299           inbound          reverse
# 299    HPa    1      4            300           inbound          reverse
# 300    HPa    1      4            301           inbound          reverse
# 301    HPa    1      4            302           inbound          forward
# 302    HPa    1      4            303           inbound          forward
# 303    HPa    1      4            304           inbound          reverse
# 304    HPa    1      4            305           inbound          reverse
# 305    HPa    1      4            306           inbound          reverse
# 306    HPa    1      4            307           inbound          forward
# 307    HPa    1      4            308           inbound          reverse
# 308    HPa    1      4            309           inbound          reverse
# 309    HPa    1      4            310           inbound          reverse
# 310    HPa    1      4            311           inbound          forward
# 311    HPa    1      4            312           inbound          forward
# 312    HPa    1      4            313           inbound          forward
# 313    HPa    1      4            314          outbound          reverse
# 314    HPa    1      4            315           inbound          forward
# 315    HPa    1      4            316          outbound          reverse
# 316    HPa    1      4            317          outbound          forward
# 317    HPa    1      4            318          outbound          reverse
# 318    HPa    1      4            319           inbound          forward
# 319    HPa    1      4            320           inbound          forward
# 320    HPa    1      4            321          outbound          reverse
#
#      ripple_state_probability  ripple_start_time  ripple_end_time  \
# 0                    0.802458        5868.271933      5868.376600
# 1                    0.697151        5871.522600      5871.571933
# 2                    0.771316        5872.833933      5872.924600
# 3                    0.979445        5873.975267      5874.051267
# 4                    0.626714        5878.145933      5878.177933
# 5                    0.522266        5879.346600      5879.387933
# 6                    0.489930        5880.773933      5880.895933
# 7                    0.486252        5882.797933      5882.865933
# 8                    0.661648        5886.325267      5886.400600
# 9                    0.417340        5888.555267      5888.589933
# 10                   0.613722        5893.770600      5893.862600
# 11                   0.435207        5905.398600      5905.449267
# 12                   0.724517        5906.185933      5906.228600
# 13                   0.750517        5923.599933      5923.675933
# 14                   0.460585        5943.293933      5943.364600
# 15                   0.711419        5943.985267      5944.117933
# 16                   0.324242        5944.284600      5944.323933
# 17                   0.731048        5947.649267      5947.735933
# 18                   0.642750        5957.500600      5957.585267
# 19                   0.734067        5981.460600      5981.514600
# 20                   0.929041        6004.254600      6004.285267
# 21                   0.637081        6013.857267      6013.925933
# 22                   0.753597        6024.310600      6024.463933
# 23                   0.612612        6039.195267      6039.280600
# 24                   0.997076        6051.057267      6051.105267
# 25                   0.686200        6072.188600      6072.247267
# 26                   0.443261        6075.463933      6075.491267
# 27                   0.505067        6102.315267      6102.346600
# 28                   0.530839        6107.581933      6107.653933
# 29                   0.340460        6107.667933      6107.713933
# ..                        ...                ...              ...
# 291                  0.649990        7001.765933      7001.827267
# 292                  0.910473        7016.017933      7016.099933
# 293                  0.813866        7016.140600      7016.246600
# 294                  0.493013        7019.079933      7019.119267
# 295                  0.552346        7031.193933      7031.240600
# 296                  0.501904        7038.486600      7038.659267
# 297                  0.982195        7038.673933      7038.719267
# 298                  0.562882        7040.084600      7040.266600
# 299                  0.686324        7041.189267      7041.253267
# 300                  0.560234        7041.875267      7041.957267
# 301                  0.630313        7041.963267      7042.051933
# 302                  0.592935        7042.783933      7042.901933
# 303                  0.574481        7042.926600      7042.982600
# 304                  0.668247        7043.553267      7043.599933
# 305                  0.831279        7045.002600      7045.086600
# 306                  0.547089        7045.228600      7045.283267
# 307                  0.840091        7045.911933      7045.957933
# 308                  0.608672        7046.476600      7046.549933
# 309                  0.742935        7046.570600      7046.635267
# 310                  0.590585        7047.659933      7047.751267
# 311                  0.698792        7047.765933      7047.795267
# 312                  0.761483        7047.837267      7047.928600
# 313                  0.626884        7056.933267      7056.980600
# 314                  0.693967        7059.139933      7059.194600
# 315                  0.586670        7062.851267      7062.881933
# 316                  0.517191        7071.328600      7071.388600
# 317                  0.519502        7071.622600      7071.669267
# 318                  0.844341        7071.723933      7071.776600
# 319                  0.498901        7072.266600      7072.360600
# 320                  0.761742        7073.040600      7073.084600
#
#      number_of_unique_neurons_spiking  number_of_spikes session_time is_spike
# 0                                   9               112        early  isSpike
# 1                                   9                59        early  isSpike
# 2                                  12               253        early  isSpike
# 3                                   9               147        early  isSpike
# 4                                   8                27        early  isSpike
# 5                                   7                44        early  isSpike
# 6                                  11                94        early  isSpike
# 7                                  10                40        early  isSpike
# 8                                  12               204        early  isSpike
# 9                                   8                25        early  isSpike
# 10                                 12               219        early  isSpike
# 11                                  8                55        early  isSpike
# 12                                  8                43        early  isSpike
# 13                                 11                47        early  isSpike
# 14                                  9                65        early  isSpike
# 15                                 12               165        early  isSpike
# 16                                  8                33        early  isSpike
# 17                                  9               116        early  isSpike
# 18                                 13               134        early  isSpike
# 19                                 11                85        early  isSpike
# 20                                  7                18        early  isSpike
# 21                                 13               146        early  isSpike
# 22                                 11               253        early  isSpike
# 23                                 12               102        early  isSpike
# 24                                  9                63        early  isSpike
# 25                                  9                76        early  isSpike
# 26                                  7                20        early  isSpike
# 27                                  8                16        early  isSpike
# 28                                  8                60        early  isSpike
# 29                                  9                36        early  isSpike
# ..                                ...               ...          ...      ...
# 291                                12               149         late  isSpike
# 292                                10               216         late  isSpike
# 293                                11               208         late  isSpike
# 294                                12                48         late  isSpike
# 295                                11                71         late  isSpike
# 296                                12               419         late  isSpike
# 297                                 9                87         late  isSpike
# 298                                12               290         late  isSpike
# 299                                 9               122         late  isSpike
# 300                                13               148         late  isSpike
# 301                                12               165         late  isSpike
# 302                                12               273         late  isSpike
# 303                                 9               124         late  isSpike
# 304                                10                52         late  isSpike
# 305                                13               122         late  isSpike
# 306                                12                92         late  isSpike
# 307                                10                70         late  isSpike
# 308                                10               123         late  isSpike
# 309                                10                88         late  isSpike
# 310                                12               221         late  isSpike
# 311                                 9                71         late  isSpike
# 312                                12               132         late  isSpike
# 313                                 8                58         late  isSpike
# 314                                11               115         late  isSpike
# 315                                 8                48         late  isSpike
# 316                                10                31         late  isSpike
# 317                                 8                37         late  isSpike
# 318                                11                97         late  isSpike
# 319                                10                97         late  isSpike
# 320                                11                79         late  isSpike
#
# [321 rows x 13 columns]
