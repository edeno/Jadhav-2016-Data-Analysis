# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
# %qtconsole

# %%
import pandas as pd
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from collections import namedtuple

Animal = namedtuple('Animal', {'directory', 'short_name'})
ANIMALS = {
    'HPa': Animal(directory='HPa_direct', short_name='HPa'),
    'HPb': Animal(directory='HPb_direct', short_name='HPb'),
    'HPc': Animal(directory='HPc_direct', short_name='HPc'),
    'Bond': Animal(directory='Bond', short_name='bon')
}

ANIMALS
# Out:
# {'Bond': Animal(directory='Bond', short_name='bon'),
#  'HPa': Animal(directory='HPa_direct', short_name='HPa'),
#  'HPb': Animal(directory='HPb_direct', short_name='HPb'),
#  'HPc': Animal(directory='HPc_direct', short_name='HPc')}

# %%
from os.path import join
from glob import glob
from src.data_processing import RAW_DATA_DIR
from scipy.io import loadmat
import re

def load_task(file_name, animal):
    data = loadmat(file_name, variable_names=('task'))['task']
    day = data.shape[-1]
    epochs = data[0, -1][0]
    n_epochs = len(epochs)
    index = pd.MultiIndex.from_product(
        ([animal.short_name], [day], np.arange(n_epochs) + 1),
        names=['animal', 'day', 'epoch'])
    
    return pd.DataFrame(
        [{name: epoch[name][0][0][0].squeeze()
         for name in epoch.dtype.names
         if name in ['environment', 'exposure', 'type']}
        for epoch in epochs]).set_index(index)

def get_task(animal):
    task_files = glob(join(RAW_DATA_DIR, animal.directory, '*task*.mat'))
    return pd.concat(load_task(task_file, animal) for task_file in task_files)

# %%
get_task(ANIMALS['HPa'])
# Out:
#                  environment   type
# animal day epoch
# HPa    1   1        presleep  sleep
#            2             lin    run
#            3             NaN   rest
#            4            wtr1    run
#            5             NaN   rest
#            6            wtr1    run
#            7       postsleep  sleep
#        2   1        presleep  sleep
#            2            wtr1    run
#            3             NaN   rest
#            4            wtr1    run
#            5       postsleep  sleep
#        3   1        presleep  sleep
#            2            wtr1    run
#            3             NaN   rest
#            4            wtr1    run
#            5       postsleep  sleep
#        4   1        presleep  sleep
#            2            wtr1    run
#            3             NaN   rest
#            4            wtr1    run
#            5       postsleep  sleep
#        5   1        presleep  sleep
#            2            wtr1    run
#            3             NaN   rest
#            4            wtr1    run
#            5       postsleep  sleep
#        6   1        presleep  sleep
#            2            wtr1    run
#            3             NaN   rest
#            4            wtr2    run
#            5       postsleep  sleep
#        7   1        presleep  sleep
#            2            wtr1    run
#            3             NaN   rest
#            4            wtr2    run
#            5       postsleep  sleep
#        8   1        presleep  sleep
#            2            wtr1    run
#            3             NaN   rest
#            4            wtr2    run
#            5       postsleep  sleep

# %%
get_task(ANIMALS['Bond'])
# Out:
#                  environment exposure   type
# animal day epoch
# bon    3   1             NaN      NaN  sleep
#            2          TrackB        1    run
#            3             NaN      NaN  sleep
#            4          TrackB        2    run
#            5             NaN      NaN  sleep
#            6          TrackA       13    run
#            7             NaN      NaN  sleep
#        4   1             NaN      NaN  sleep
#            2          TrackB        3    run
#            3             NaN      NaN  sleep
#            4          TrackB        4    run
#            5             NaN      NaN  sleep
#            6          TrackA       14    run
#            7             NaN      NaN  sleep
#        5   1             NaN      NaN  sleep
#            2          TrackB        5    run
#            3             NaN      NaN  sleep
#            4          TrackB        6    run
#            5             NaN      NaN  sleep
#            6          TrackA       15    run
#            7             NaN      NaN  sleep
#            8             NaN      NaN    NaN
#            9             NaN      NaN    NaN
#        6   1             NaN      NaN  sleep
#            2          TrackB        7    run
#            3             NaN      NaN  sleep
#            4          TrackB        8    run
#            5             NaN      NaN  sleep
#            6          TrackA       16    run
#            7             NaN      NaN  sleep
#        7   1             NaN      NaN  sleep
#            2          TrackB        9    run
#            3             NaN      NaN  sleep
#            4          TrackB       10    run
#            5             NaN      NaN  sleep
#            6          TrackA       17    run
#            7             NaN      NaN  sleep
#        8   1             NaN      NaN  sleep
#            2          TrackB       11    run
#            3             NaN      NaN  sleep
#            4          TrackB       12    run
#            5             NaN      NaN  sleep
#            6          TrackA       18    run
#            7             NaN      NaN  sleep
#        9   1             NaN      NaN  sleep
#            2          TrackB       13    run
#            3             NaN      NaN  sleep
#            4          TrackB       14    run
#            5             NaN      NaN  sleep
#            6          TrackA       19    run
#            7             NaN      NaN  sleep
#        10  1             NaN      NaN  sleep
#            2          TrackB       15    run
#            3             NaN      NaN  sleep
#            4          TrackB       16    run
#            5             NaN      NaN  sleep
#            6          TrackA       20    run
#            7             NaN      NaN  sleep

# %%
pd.concat((get_task(ANIMALS['Bond']), get_task(ANIMALS['HPa'])))
# Out:
#                  environment exposure   type
# animal day epoch
# bon    3   1             NaN      NaN  sleep
#            2          TrackB        1    run
#            3             NaN      NaN  sleep
#            4          TrackB        2    run
#            5             NaN      NaN  sleep
#            6          TrackA       13    run
#            7             NaN      NaN  sleep
#        4   1             NaN      NaN  sleep
#            2          TrackB        3    run
#            3             NaN      NaN  sleep
#            4          TrackB        4    run
#            5             NaN      NaN  sleep
#            6          TrackA       14    run
#            7             NaN      NaN  sleep
#        5   1             NaN      NaN  sleep
#            2          TrackB        5    run
#            3             NaN      NaN  sleep
#            4          TrackB        6    run
#            5             NaN      NaN  sleep
#            6          TrackA       15    run
#            7             NaN      NaN  sleep
#            8             NaN      NaN    NaN
#            9             NaN      NaN    NaN
#        6   1             NaN      NaN  sleep
#            2          TrackB        7    run
#            3             NaN      NaN  sleep
#            4          TrackB        8    run
#            5             NaN      NaN  sleep
#            6          TrackA       16    run
#            7             NaN      NaN  sleep
# ...                      ...      ...    ...
# HPa    3   1        presleep      NaN  sleep
#            2            wtr1      NaN    run
#            3             NaN      NaN   rest
#            4            wtr1      NaN    run
#            5       postsleep      NaN  sleep
#        4   1        presleep      NaN  sleep
#            2            wtr1      NaN    run
#            3             NaN      NaN   rest
#            4            wtr1      NaN    run
#            5       postsleep      NaN  sleep
#        5   1        presleep      NaN  sleep
#            2            wtr1      NaN    run
#            3             NaN      NaN   rest
#            4            wtr1      NaN    run
#            5       postsleep      NaN  sleep
#        6   1        presleep      NaN  sleep
#            2            wtr1      NaN    run
#            3             NaN      NaN   rest
#            4            wtr2      NaN    run
#            5       postsleep      NaN  sleep
#        7   1        presleep      NaN  sleep
#            2            wtr1      NaN    run
#            3             NaN      NaN   rest
#            4            wtr2      NaN    run
#            5       postsleep      NaN  sleep
#        8   1        presleep      NaN  sleep
#            2            wtr1      NaN    run
#            3             NaN      NaN   rest
#            4            wtr2      NaN    run
#            5       postsleep      NaN  sleep
#
# [100 rows x 3 columns]

# %%
pd.concat([get_task(animal) for animal in  ANIMALS.values()]).sort_index()
# Out:
#                  environment exposure   type
# animal day epoch
# HPa    1   1        presleep      NaN  sleep
#            2             lin      NaN    run
#            3             NaN      NaN   rest
#            4            wtr1      NaN    run
#            5             NaN      NaN   rest
#            6            wtr1      NaN    run
#            7       postsleep      NaN  sleep
#        2   1        presleep      NaN  sleep
#            2            wtr1      NaN    run
#            3             NaN      NaN   rest
#            4            wtr1      NaN    run
#            5       postsleep      NaN  sleep
#        3   1        presleep      NaN  sleep
#            2            wtr1      NaN    run
#            3             NaN      NaN   rest
#            4            wtr1      NaN    run
#            5       postsleep      NaN  sleep
#        4   1        presleep      NaN  sleep
#            2            wtr1      NaN    run
#            3             NaN      NaN   rest
#            4            wtr1      NaN    run
#            5       postsleep      NaN  sleep
#        5   1        presleep      NaN  sleep
#            2            wtr1      NaN    run
#            3             NaN      NaN   rest
#            4            wtr1      NaN    run
#            5       postsleep      NaN  sleep
#        6   1        presleep      NaN  sleep
#            2            wtr1      NaN    run
#            3             NaN      NaN   rest
# ...                      ...      ...    ...
# bon    6   6          TrackA       16    run
#            7             NaN      NaN  sleep
#        7   1             NaN      NaN  sleep
#            2          TrackB        9    run
#            3             NaN      NaN  sleep
#            4          TrackB       10    run
#            5             NaN      NaN  sleep
#            6          TrackA       17    run
#            7             NaN      NaN  sleep
#        8   1             NaN      NaN  sleep
#            2          TrackB       11    run
#            3             NaN      NaN  sleep
#            4          TrackB       12    run
#            5             NaN      NaN  sleep
#            6          TrackA       18    run
#            7             NaN      NaN  sleep
#        9   1             NaN      NaN  sleep
#            2          TrackB       13    run
#            3             NaN      NaN  sleep
#            4          TrackB       14    run
#            5             NaN      NaN  sleep
#            6          TrackA       19    run
#            7             NaN      NaN  sleep
#        10  1             NaN      NaN  sleep
#            2          TrackB       15    run
#            3             NaN      NaN  sleep
#            4          TrackB       16    run
#            5             NaN      NaN  sleep
#            6          TrackA       20    run
#            7             NaN      NaN  sleep
#
# [184 rows x 3 columns]

# %%
from src.data_processing import make_epochs_dataframe

epoch_info = make_epochs_dataframe(ANIMALS)
epoch_info
# Out:
#                  environment exposure   type
# animal day epoch
# HPa    1   1        presleep      NaN  sleep
#            2             lin      NaN    run
#            3             NaN      NaN   rest
#            4            wtr1      NaN    run
#            5             NaN      NaN   rest
#            6            wtr1      NaN    run
#            7       postsleep      NaN  sleep
#        2   1        presleep      NaN  sleep
#            2            wtr1      NaN    run
#            3             NaN      NaN   rest
#            4            wtr1      NaN    run
#            5       postsleep      NaN  sleep
#        3   1        presleep      NaN  sleep
#            2            wtr1      NaN    run
#            3             NaN      NaN   rest
#            4            wtr1      NaN    run
#            5       postsleep      NaN  sleep
#        4   1        presleep      NaN  sleep
#            2            wtr1      NaN    run
#            3             NaN      NaN   rest
#            4            wtr1      NaN    run
#            5       postsleep      NaN  sleep
#        5   1        presleep      NaN  sleep
#            2            wtr1      NaN    run
#            3             NaN      NaN   rest
#            4            wtr1      NaN    run
#            5       postsleep      NaN  sleep
#        6   1        presleep      NaN  sleep
#            2            wtr1      NaN    run
#            3             NaN      NaN   rest
# ...                      ...      ...    ...
# bon    6   6          TrackA       16    run
#            7             NaN      NaN  sleep
#        7   1             NaN      NaN  sleep
#            2          TrackB        9    run
#            3             NaN      NaN  sleep
#            4          TrackB       10    run
#            5             NaN      NaN  sleep
#            6          TrackA       17    run
#            7             NaN      NaN  sleep
#        8   1             NaN      NaN  sleep
#            2          TrackB       11    run
#            3             NaN      NaN  sleep
#            4          TrackB       12    run
#            5             NaN      NaN  sleep
#            6          TrackA       18    run
#            7             NaN      NaN  sleep
#        9   1             NaN      NaN  sleep
#            2          TrackB       13    run
#            3             NaN      NaN  sleep
#            4          TrackB       14    run
#            5             NaN      NaN  sleep
#            6          TrackA       19    run
#            7             NaN      NaN  sleep
#        10  1             NaN      NaN  sleep
#            2          TrackB       15    run
#            3             NaN      NaN  sleep
#            4          TrackB       16    run
#            5             NaN      NaN  sleep
#            6          TrackA       20    run
#            7             NaN      NaN  sleep
#
# [184 rows x 3 columns]

# %%
epoch_keys = epoch_info[(epoch_info.type == 'run') & (epoch_info.environment != 'lin')].index
epoch_keys.tolist()
# Out:
# [('HPa', 1, 4),
#  ('HPa', 1, 6),
#  ('HPa', 2, 2),
#  ('HPa', 2, 4),
#  ('HPa', 3, 2),
#  ('HPa', 3, 4),
#  ('HPa', 4, 2),
#  ('HPa', 4, 4),
#  ('HPa', 5, 2),
#  ('HPa', 5, 4),
#  ('HPa', 6, 2),
#  ('HPa', 6, 4),
#  ('HPa', 7, 2),
#  ('HPa', 7, 4),
#  ('HPa', 8, 2),
#  ('HPa', 8, 4),
#  ('HPb', 1, 4),
#  ('HPb', 1, 6),
#  ('HPb', 2, 2),
#  ('HPb', 2, 4),
#  ('HPb', 3, 2),
#  ('HPb', 3, 4),
#  ('HPb', 4, 2),
#  ('HPb', 4, 4),
#  ('HPb', 5, 2),
#  ('HPb', 5, 4),
#  ('HPb', 6, 2),
#  ('HPb', 6, 4),
#  ('HPb', 7, 2),
#  ('HPb', 7, 4),
#  ('HPb', 8, 2),
#  ('HPb', 8, 4),
#  ('HPc', 1, 4),
#  ('HPc', 1, 6),
#  ('HPc', 2, 2),
#  ('HPc', 2, 4),
#  ('HPc', 3, 2),
#  ('HPc', 3, 4),
#  ('HPc', 4, 2),
#  ('HPc', 4, 4),
#  ('HPc', 5, 2),
#  ('HPc', 5, 4),
#  ('HPc', 6, 2),
#  ('HPc', 6, 4),
#  ('HPc', 7, 2),
#  ('HPc', 7, 4),
#  ('HPc', 8, 2),
#  ('HPc', 8, 4),
#  ('bon', 3, 2),
#  ('bon', 3, 4),
#  ('bon', 3, 6),
#  ('bon', 4, 2),
#  ('bon', 4, 4),
#  ('bon', 4, 6),
#  ('bon', 5, 2),
#  ('bon', 5, 4),
#  ('bon', 5, 6),
#  ('bon', 6, 2),
#  ('bon', 6, 4),
#  ('bon', 6, 6),
#  ('bon', 7, 2),
#  ('bon', 7, 4),
#  ('bon', 7, 6),
#  ('bon', 8, 2),
#  ('bon', 8, 4),
#  ('bon', 8, 6),
#  ('bon', 9, 2),
#  ('bon', 9, 4),
#  ('bon', 9, 6),
#  ('bon', 10, 2),
#  ('bon', 10, 4),
#  ('bon', 10, 6)]

# %%
from src.analysis import detect_epoch_ripples
from src.parameters import SAMPLING_FREQUENCY

epoch_key = ('bon', 10, 6)
ripple_times = detect_epoch_ripples(
        epoch_key, ANIMALS, sampling_frequency=SAMPLING_FREQUENCY)
ripple_times
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-684-cd4ba3b5a28d> in <module>()
#       4 epoch_key = ('bon', 10, 6)
#       5 ripple_times = detect_epoch_ripples(
# ----> 6         epoch_key, ANIMALS, sampling_frequency=SAMPLING_FREQUENCY)
#       7 ripple_times
#
# ~/Documents/GitHub/Jadhav-2016-Data-Analysis/src/analysis.py in detect_epoch_ripples(epoch_key, animals, sampling_frequency, ripple_detection_function, ripple_detection_kwargs, speed_threshold)
#     324                         for tetrode_key in tetrode_keys]
#     325     candidate_ripple_times = ripple_detection_function(
# --> 326         hippocampus_lfps, **ripple_detection_kwargs)
#     327     return exclude_movement_during_ripples(
#     328         candidate_ripple_times, epoch_key, animals, speed_threshold)
#
# ~/Documents/GitHub/Jadhav-2016-Data-Analysis/src/ripple_detection.py in Kay_method(lfps, minimum_duration, zscore_threshold, smoothing_sigma, sampling_frequency)
#      93         minimum_duration=minimum_duration,
#      94         zscore_threshold=zscore_threshold, sigma=smoothing_sigma,
# ---> 95         sampling_frequency=sampling_frequency)
#      96
#      97
#
# ~/Documents/GitHub/Jadhav-2016-Data-Analysis/src/ripple_detection.py in _get_candidate_ripples_Kay(filtered_lfps, is_multitaper, minimum_duration, zscore_threshold, sigma, sampling_frequency)
#     164         thresholded_combined_lfps.is_above_mean,
#     165         thresholded_combined_lfps.is_above_threshold,
# --> 166         minimum_duration=minimum_duration)))
#     167
#     168
#
# ~/Documents/GitHub/Jadhav-2016-Data-Analysis/src/ripple_detection.py in _extend_threshold_to_mean(is_above_mean, is_above_threshold, minimum_duration)
#     258     '''
#     259     above_mean_segments = segment_boolean_series(
# --> 260         is_above_mean, minimum_duration=minimum_duration)
#     261     above_threshold_segments = segment_boolean_series(
#     262         is_above_threshold, minimum_duration=minimum_duration)
#
# ~/Documents/GitHub/Jadhav-2016-Data-Analysis/src/ripple_detection.py in segment_boolean_series(series, minimum_duration)
#      39
#      40     return [(start_time, end_time)
# ---> 41             for start_time, end_time in zip(start_times, end_times)
#      42             if end_time >= (start_time + minimum_duration)]
#      43
#
# ~/Documents/GitHub/Jadhav-2016-Data-Analysis/src/ripple_detection.py in <listcomp>(.0)
#      40     return [(start_time, end_time)
#      41             for start_time, end_time in zip(start_times, end_times)
# ---> 42             if end_time >= (start_time + minimum_duration)]
#      43
#      44
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib._Timestamp.__richcmp__ (pandas/_libs/tslib.c:20281)()
#
# TypeError: Cannot compare type 'Timestamp' with type 'int'

# %%
from src.analysis import decode_ripple_clusterless

(ripple_info, decision_state_probability,
 posterior_density) = decode_ripple_clusterless(
    epoch_key, ANIMALS, ripple_times)
# Out:
# > /Users/edeno/Documents/GitHub/Jadhav-2016-Data-Analysis/src/data_processing.py(566)get_mark_dataframe()
# -> mark_data[:, mark_names.index('time')] = mark_data[
# (Pdb) mark_data[         :, mark_names.index('time')]
# array([ 18825687.,  18826208.,  18828062., ...,  92696353.,  92701652.,
#         92701826.])
# (Pdb) pd.to_datatime(mark_data[:, mark_names.index('time')]))
# *** SyntaxError: invalid syntax
# (Pdb) pd.to_datetime(mark_data[:, mark_names.index('time')])
# DatetimeIndex(['1970-01-01 00:00:00.018825687',
#                '1970-01-01 00:00:00.018826208',
#                '1970-01-01 00:00:00.018828062',
#                '1970-01-01 00:00:00.018828987',
#                '1970-01-01 00:00:00.018832048',
#                '1970-01-01 00:00:00.018834372',
#                '1970-01-01 00:00:00.018835773',
#                '1970-01-01 00:00:00.018836697',
#                '1970-01-01 00:00:00.018838137',
#                '1970-01-01 00:00:00.018841048',
#                ...
#                '1970-01-01 00:00:00.092658332',
#                '1970-01-01 00:00:00.092663976',
#                '1970-01-01 00:00:00.092666474',
#                '1970-01-01 00:00:00.092681343',
#                '1970-01-01 00:00:00.092687758',
#                '1970-01-01 00:00:00.092688071',
#                '1970-01-01 00:00:00.092691112',
#                '1970-01-01 00:00:00.092696353',
#                '1970-01-01 00:00:00.092701652',
#                '1970-01-01 00:00:00.092701826'],
#               dtype='datetime64[ns]', length=41622, freq=None)
# (Pdb) pd.to_datetime(mark_data[:, mark_names.index('time')], unit='L')
# *** ValueError: cannot cast unit L
# (Pdb) pd.to_datetime(mark_data[:, mark_names.index('time')], unit='U')
# *** ValueError: cannot cast unit U
# (Pdb) pd.to_datetime(mark_data[:, mark_names.index('time')], unit='ns')
# DatetimeIndex(['1970-01-01 00:00:00.018825687',
#                '1970-01-01 00:00:00.018826208',
#                '1970-01-01 00:00:00.018828062',
#                '1970-01-01 00:00:00.018828987',
#                '1970-01-01 00:00:00.018832048',
#                '1970-01-01 00:00:00.018834372',
#                '1970-01-01 00:00:00.018835773',
#                '1970-01-01 00:00:00.018836697',
#                '1970-01-01 00:00:00.018838137',
#                '1970-01-01 00:00:00.018841048',
#                ...
#                '1970-01-01 00:00:00.092658332',
#                '1970-01-01 00:00:00.092663976',
#                '1970-01-01 00:00:00.092666474',
#                '1970-01-01 00:00:00.092681343',
#                '1970-01-01 00:00:00.092687758',
#                '1970-01-01 00:00:00.092688071',
#                '1970-01-01 00:00:00.092691112',
#                '1970-01-01 00:00:00.092696353',
#                '1970-01-01 00:00:00.092701652',
#                '1970-01-01 00:00:00.092701826'],
#               dtype='datetime64[ns]', length=41622, freq=None)
# (Pdb) pd.to_datetime(mark_data[:, mark_names.index('time')], unit='us')
# DatetimeIndex(['1970-01-01 00:00:18.825687', '1970-01-01 00:00:18.826208',
#                '1970-01-01 00:00:18.828062', '1970-01-01 00:00:18.828987',
#                '1970-01-01 00:00:18.832048', '1970-01-01 00:00:18.834372',
#                '1970-01-01 00:00:18.835773', '1970-01-01 00:00:18.836697',
#                '1970-01-01 00:00:18.838137', '1970-01-01 00:00:18.841048',
#                ...
#                '1970-01-01 00:01:32.658332', '1970-01-01 00:01:32.663976',
#                '1970-01-01 00:01:32.666474', '1970-01-01 00:01:32.681343',
#                '1970-01-01 00:01:32.687758', '1970-01-01 00:01:32.688071',
#                '1970-01-01 00:01:32.691112', '1970-01-01 00:01:32.696353',
#                '1970-01-01 00:01:32.701652', '1970-01-01 00:01:32.701826'],
#               dtype='datetime64[ns]', length=41622, freq=None)
# (Pdb) mark_data[:, mark_names.index('time')]
# array([ 18825687.,  18826208.,  18828062., ...,  92696353.,  92701652.,
#         92701826.])
# (Pdb) mark_data[:, mark_names.index('time')] / 1E4
# array([ 1882.5687,  1882.6208,  1882.8062, ...,  9269.6353,  9270.1652,
#         9270.1826])
# (Pdb) pd.to_datetime(mark_data[:, mark_names.index('time')], unit='ms')
# DatetimeIndex(['1970-01-01 05:13:45.687000', '1970-01-01 05:13:46.208000',
#                '1970-01-01 05:13:48.062000', '1970-01-01 05:13:48.987000',
#                '1970-01-01 05:13:52.048000', '1970-01-01 05:13:54.372000',
#                '1970-01-01 05:13:55.773000', '1970-01-01 05:13:56.697000',
#                '1970-01-01 05:13:58.137000', '1970-01-01 05:14:01.048000',
#                ...
#                '1970-01-02 01:44:18.332000', '1970-01-02 01:44:23.976000',
#                '1970-01-02 01:44:26.474000', '1970-01-02 01:44:41.343000',
#                '1970-01-02 01:44:47.758000', '1970-01-02 01:44:48.071000',
#                '1970-01-02 01:44:51.112000', '1970-01-02 01:44:56.353000',
#                '1970-01-02 01:45:01.652000', '1970-01-02 01:45:01.826000'],
#               dtype='datetime64[ns]', length=41622, freq=None)
# (Pdb) pd.to_datetime(mark_data[         :, mark_names.index('time')], unit='us')
# DatetimeIndex(['1970-01-01 00:00:18.825687', '1970-01-01 00:00:18.826208',
#                '1970-01-01 00:00:18.828062', '1970-01-01 00:00:18.828987',
#                '1970-01-01 00:00:18.832048', '1970-01-01 00:00:18.834372',
#                '1970-01-01 00:00:18.835773', '1970-01-01 00:00:18.836697',
#                '1970-01-01 00:00:18.838137', '1970-01-01 00:00:18.841048',
#                ...
#                '1970-01-01 00:01:32.658332', '1970-01-01 00:01:32.663976',
#                '1970-01-01 00:01:32.666474', '1970-01-01 00:01:32.681343',
#                '1970-01-01 00:01:32.687758', '1970-01-01 00:01:32.688071',
#                '1970-01-01 00:01:32.691112', '1970-01-01 00:01:32.696353',
#                '1970-01-01 00:01:32.701652', '1970-01-01 00:01:32.701826'],
#               dtype='datetime64[ns]', length=41622, freq=None)
# (Pdb) mark_names
# ['time', 'channel_1_max', 'channel_2_max', 'channel_3_max', 'channel_4_max', 'max_width', 'max_height_change', 'x_position', 'y_position']
# (Pdb) pd.to_datetime(mark_data[         :, mark_names.index('time')], unit='ms')
# DatetimeIndex(['1970-01-01 05:13:45.687000', '1970-01-01 05:13:46.208000',
#                '1970-01-01 05:13:48.062000', '1970-01-01 05:13:48.987000',
#                '1970-01-01 05:13:52.048000', '1970-01-01 05:13:54.372000',
#                '1970-01-01 05:13:55.773000', '1970-01-01 05:13:56.697000',
#                '1970-01-01 05:13:58.137000', '1970-01-01 05:14:01.048000',
#                ...
#                '1970-01-02 01:44:18.332000', '1970-01-02 01:44:23.976000',
#                '1970-01-02 01:44:26.474000', '1970-01-02 01:44:41.343000',
#                '1970-01-02 01:44:47.758000', '1970-01-02 01:44:48.071000',
#                '1970-01-02 01:44:51.112000', '1970-01-02 01:44:56.353000',
#                '1970-01-02 01:45:01.652000', '1970-01-02 01:45:01.826000'],
#               dtype='datetime64[ns]', length=41622, freq=None)
# (Pdb) blah = pd.to_datetime(mark_data[         :, mark_names.index('time')], unit='ms')
# (Pdb) blah
# DatetimeIndex(['1970-01-01 05:13:45.687000', '1970-01-01 05:13:46.208000',
#                '1970-01-01 05:13:48.062000', '1970-01-01 05:13:48.987000',
#                '1970-01-01 05:13:52.048000', '1970-01-01 05:13:54.372000',
#                '1970-01-01 05:13:55.773000', '1970-01-01 05:13:56.697000',
#                '1970-01-01 05:13:58.137000', '1970-01-01 05:14:01.048000',
#                ...
#                '1970-01-02 01:44:18.332000', '1970-01-02 01:44:23.976000',
#                '1970-01-02 01:44:26.474000', '1970-01-02 01:44:41.343000',
#                '1970-01-02 01:44:47.758000', '1970-01-02 01:44:48.071000',
#                '1970-01-02 01:44:51.112000', '1970-01-02 01:44:56.353000',
#                '1970-01-02 01:45:01.652000', '1970-01-02 01:45:01.826000'],
#               dtype='datetime64[ns]', length=41622, freq=None)
# (Pdb) blah[1] - blah[0]
# Timedelta('0 days 00:00:00.521000')
# (Pdb) mark_file
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# (Pdb) mark_file.keys()
# dict_keys(['__globals__', 'filedata', '__version__', '__header__'])
# (Pdb) mark_file['filedata'][0, 0].keys()
# *** AttributeError: 'numpy.void' object has no attribute 'keys'
# (Pdb) mark_file['filedata'][0, 0].dtype.names
# ('params', 'paramnames', 'filename')
# (Pdb) mark_file['filedata'][0, 0]['filename']
# array(['bond10-03'],
#       dtype='<U9')
# (Pdb) mark_file['filedata'][0, 0]['paramnames']
# array([[array(['Time'],
#       dtype='<U4')],
#        [array(['Channel 1 Max'],
#       dtype='<U13')],
#        [array(['Channel 2 Max'],
#       dtype='<U13')],
#        [array(['Channel 3 Max'],
#       dtype='<U13')],
#        [array(['Channel 4 Max'],
#       dtype='<U13')],
#        [array(['Max width'],
#       dtype='<U9')],
#        [array(['Max height change'],
#       dtype='<U17')],
#        [array(['X position'],
#       dtype='<U10')],
#        [array(['Y position'],
#       dtype='<U10')]], dtype=object)
# (Pdb) time_index = pd.to_datetime(mark_data[         :, mark_names.index('time')], unit='us')
# (Pdb) time_index
# DatetimeIndex(['1970-01-01 00:00:18.825687', '1970-01-01 00:00:18.826208',
#                '1970-01-01 00:00:18.828062', '1970-01-01 00:00:18.828987',
#                '1970-01-01 00:00:18.832048', '1970-01-01 00:00:18.834372',
#                '1970-01-01 00:00:18.835773', '1970-01-01 00:00:18.836697',
#                '1970-01-01 00:00:18.838137', '1970-01-01 00:00:18.841048',
#                ...
#                '1970-01-01 00:01:32.658332', '1970-01-01 00:01:32.663976',
#                '1970-01-01 00:01:32.666474', '1970-01-01 00:01:32.681343',
#                '1970-01-01 00:01:32.687758', '1970-01-01 00:01:32.688071',
#                '1970-01-01 00:01:32.691112', '1970-01-01 00:01:32.696353',
#                '1970-01-01 00:01:32.701652', '1970-01-01 00:01:32.701826'],
#               dtype='datetime64[ns]', length=41622, freq=None)
# (Pdb) time_index[1] - time_index[0]
# Timedelta('0 days 00:00:00.000521')
# (Pdb) blah = time_index[1] - time_index[0]
# (Pdb) blah.secodns
# *** AttributeError: 'Timedelta' object has no attribute 'secodns'
# (Pdb) blah.to_seconds
# *** AttributeError: 'Timedelta' object has no attribute 'to_seconds'
# (Pdb) dir(blah)
# ['__abs__', '__add__', '__array_priority__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__inv__', '__le__', '__lt__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__pos__', '__pyx_vtable__', '__radd__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmod__', '__rmul__', '__rsub__', '__rtruediv__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__weakref__', '_binary_op_method_timedeltalike', '_d', '_ensure_components', '_h', '_has_ns', '_m', '_ms', '_ns', '_op_unary_method', '_repr_base', '_round', '_s', '_sign', '_us', '_validate_ops_compat', 'asm8', 'ceil', 'components', 'days', 'delta', 'floor', 'freq', 'is_populated', 'isoformat', 'max', 'microseconds', 'min', 'nanoseconds', 'resolution', 'round', 'seconds', 'to_pytimedelta', 'to_timedelta64', 'total_seconds', 'value', 'view']
# (Pdb) blah.total_seconds
# <bound method Timedelta.total_seconds of Timedelta('0 days 00:00:00.000521')>
# (Pdb) blah.value
# 521000
# (Pdb) 1 / blah.total_seconds
# *** TypeError: unsupported operand type(s) for /: 'int' and 'method'
# (Pdb) 1 / blah.total_seconds()
# 1919.3857965451057
# (Pdb) (mark_data[         :, mark_names.index('time')
# *** SyntaxError: unexpected EOF while parsing
# (Pdb) mark_data[:, mark_names.index('time')
# *** SyntaxError: unexpected EOF while parsing
# (Pdb) (mark_data[         :, mark_names.index('time')]
# *** SyntaxError: unexpected EOF while parsing
# (Pdb) mark_data[:, mark_names.index('time')]
# array([ 18825687.,  18826208.,  18828062., ...,  92696353.,  92701652.,
#         92701826.])
# (Pdb) pd.to_datetime(mark_data[         :, mark_names.index('time')], unit='s')
# DatetimeIndex(['1970-08-06 21:21:27', '1970-08-06 21:30:08',
#                '1970-08-06 22:01:02', '1970-08-06 22:16:27',
#                '1970-08-06 23:07:28', '1970-08-06 23:46:12',
#                '1970-08-07 00:09:33', '1970-08-07 00:24:57',
#                '1970-08-07 00:48:57', '1970-08-07 01:37:28',
#                ...
#                '1972-12-08 10:25:32', '1972-12-08 11:59:36',
#                '1972-12-08 12:41:14', '1972-12-08 16:49:03',
#                '1972-12-08 18:35:58', '1972-12-08 18:41:11',
#                '1972-12-08 19:31:52', '1972-12-08 20:59:13',
#                '1972-12-08 22:27:32', '1972-12-08 22:30:26'],
#               dtype='datetime64[ns]', length=41622, freq=None)
# (Pdb) pd.to_datetime(mark_data[         :, mark_names.index('time')], unit='s')
# DatetimeIndex(['1970-08-06 21:21:27', '1970-08-06 21:30:08',
#                '1970-08-06 22:01:02', '1970-08-06 22:16:27',
#                '1970-08-06 23:07:28', '1970-08-06 23:46:12',
#                '1970-08-07 00:09:33', '1970-08-07 00:24:57',
#                '1970-08-07 00:48:57', '1970-08-07 01:37:28',
#                ...
#                '1972-12-08 10:25:32', '1972-12-08 11:59:36',
#                '1972-12-08 12:41:14', '1972-12-08 16:49:03',
#                '1972-12-08 18:35:58', '1972-12-08 18:41:11',
#                '1972-12-08 19:31:52', '1972-12-08 20:59:13',
#                '1972-12-08 22:27:32', '1972-12-08 22:30:26'],
#               dtype='datetime64[ns]', length=41622, freq=None)
# (Pdb) pd.to_datetime(mark_data[         :, mark_names.index('time')], unit='us')
# DatetimeIndex(['1970-01-01 00:00:18.825687', '1970-01-01 00:00:18.826208',
#                '1970-01-01 00:00:18.828062', '1970-01-01 00:00:18.828987',
#                '1970-01-01 00:00:18.832048', '1970-01-01 00:00:18.834372',
#                '1970-01-01 00:00:18.835773', '1970-01-01 00:00:18.836697',
#                '1970-01-01 00:00:18.838137', '1970-01-01 00:00:18.841048',
#                ...
#                '1970-01-01 00:01:32.658332', '1970-01-01 00:01:32.663976',
#                '1970-01-01 00:01:32.666474', '1970-01-01 00:01:32.681343',
#                '1970-01-01 00:01:32.687758', '1970-01-01 00:01:32.688071',
#                '1970-01-01 00:01:32.691112', '1970-01-01 00:01:32.696353',
#                '1970-01-01 00:01:32.701652', '1970-01-01 00:01:32.701826'],
#               dtype='datetime64[ns]', length=41622, freq=None)
# (Pdb) pd.to_datetime(mark_data[         :, mark_names.index('time')], unit='ms')
# DatetimeIndex(['1970-01-01 05:13:45.687000', '1970-01-01 05:13:46.208000',
#                '1970-01-01 05:13:48.062000', '1970-01-01 05:13:48.987000',
#                '1970-01-01 05:13:52.048000', '1970-01-01 05:13:54.372000',
#                '1970-01-01 05:13:55.773000', '1970-01-01 05:13:56.697000',
#                '1970-01-01 05:13:58.137000', '1970-01-01 05:14:01.048000',
#                ...
#                '1970-01-02 01:44:18.332000', '1970-01-02 01:44:23.976000',
#                '1970-01-02 01:44:26.474000', '1970-01-02 01:44:41.343000',
#                '1970-01-02 01:44:47.758000', '1970-01-02 01:44:48.071000',
#                '1970-01-02 01:44:51.112000', '1970-01-02 01:44:56.353000',
#                '1970-01-02 01:45:01.652000', '1970-01-02 01:45:01.826000'],
#               dtype='datetime64[ns]', length=41622, freq=None)
# (Pdb) 41622 * (1/1500)
# 27.747999999999998
# (Pdb) mark_data[         :, mark_names.index('time')] / 10000
# array([ 1882.5687,  1882.6208,  1882.8062, ...,  9269.6353,  9270.1652,
#         9270.1826])
# (Pdb) pd.to_datetime(mark_data[:, mark_names.index('time')] * 1E5, unit='ns')
# DatetimeIndex(['1970-01-01 00:31:22.568700', '1970-01-01 00:31:22.620800',
#                '1970-01-01 00:31:22.806200', '1970-01-01 00:31:22.898700',
#                '1970-01-01 00:31:23.204800', '1970-01-01 00:31:23.437200',
#                '1970-01-01 00:31:23.577300', '1970-01-01 00:31:23.669700',
#                '1970-01-01 00:31:23.813700', '1970-01-01 00:31:24.104800',
#                ...
#                '1970-01-01 02:34:25.833200', '1970-01-01 02:34:26.397600',
#                '1970-01-01 02:34:26.647400', '1970-01-01 02:34:28.134300',
#                '1970-01-01 02:34:28.775800', '1970-01-01 02:34:28.807100',
#                '1970-01-01 02:34:29.111200', '1970-01-01 02:34:29.635300',
#                '1970-01-01 02:34:30.165200', '1970-01-01 02:34:30.182600'],
#               dtype='datetime64[ns]', length=41622, freq=None)
# (Pdb) tetrode_key
# ('bon', 10, 6, 3)
# (Pdb) q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-654-7e4a30d12ce9> in <module>()
#       3 (ripple_info, decision_state_probability,
#       4  posterior_density) = decode_ripple_clusterless(
# ----> 5     epoch_key, ANIMALS, ripple_times)
#
# ~/Documents/GitHub/Jadhav-2016-Data-Analysis/src/analysis.py in decode_ripple_clusterless(epoch_key, animals, ripple_times, sampling_frequency, n_place_bins, place_std_deviation, mark_std_deviation, scheduler, scheduler_kwargs)
#     453     marks = [(get_mark_indicator_dataframe(tetrode_key, animals)
#     454               .loc[:, mark_variables])
# --> 455              for tetrode_key in hippocampal_tetrodes.index]
#     456     marks = [tetrode_marks for tetrode_marks in marks
#     457              if (tetrode_marks.loc[position_info.speed > 4, :].dropna()
#
# ~/Documents/GitHub/Jadhav-2016-Data-Analysis/src/analysis.py in <listcomp>(.0)
#     453     marks = [(get_mark_indicator_dataframe(tetrode_key, animals)
#     454               .loc[:, mark_variables])
# --> 455              for tetrode_key in hippocampal_tetrodes.index]
#     456     marks = [tetrode_marks for tetrode_marks in marks
#     457              if (tetrode_marks.loc[position_info.speed > 4, :].dropna()
#
# ~/Documents/GitHub/Jadhav-2016-Data-Analysis/src/data_processing.py in get_mark_indicator_dataframe(tetrode_key, animals)
#     588 def get_mark_indicator_dataframe(tetrode_key, animals):
#     589     time = get_trial_time(tetrode_key, animals)
# --> 590     mark_dataframe = (get_mark_dataframe(tetrode_key, animals)
#     591                       .loc[time.min():time.max()])
#     592     mark_dataframe.index = time[
#
# ~/Documents/GitHub/Jadhav-2016-Data-Analysis/src/data_processing.py in get_mark_dataframe(tetrode_key, animals)
#     564     mark_data = mark_file['filedata'][0, 0]['params']
#     565     time_index = pd.to_datetime(
# --> 566         mark_data[:, mark_names.index('time')] * TO_NANOSECONDS, unit='ns')
#     567
#     568     return (pd.DataFrame(mark_data, columns=mark_names, index=time_index)
#
# ~/Documents/GitHub/Jadhav-2016-Data-Analysis/src/data_processing.py in get_mark_dataframe(tetrode_key, animals)
#     564     mark_data = mark_file['filedata'][0, 0]['params']
#     565     time_index = pd.to_datetime(
# --> 566         mark_data[:, mark_names.index('time')] * TO_NANOSECONDS, unit='ns')
#     567
#     568     return (pd.DataFrame(mark_data, columns=mark_names, index=time_index)
#
# ~/anaconda3/envs/Jadhav-2016-Data-Analysis/lib/python3.5/bdb.py in trace_dispatch(self, frame, event, arg)
#      46             return # None
#      47         if event == 'line':
# ---> 48             return self.dispatch_line(frame)
#      49         if event == 'call':
#      50             return self.dispatch_call(frame, arg)
#
# ~/anaconda3/envs/Jadhav-2016-Data-Analysis/lib/python3.5/bdb.py in dispatch_line(self, frame)
#      65         if self.stop_here(frame) or self.break_here(frame):
#      66             self.user_line(frame)
# ---> 67             if self.quitting: raise BdbQuit
#      68         return self.trace_dispatch
#      69
#
# BdbQuit:
