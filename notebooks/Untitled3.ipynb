# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'

# %%
import pandas as pd
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

import logging
logging.basicConfig(level=logging.INFO)

from src.parameters import ANIMALS, SAMPLING_FREQUENCY

# %%
blah = xr.open_mfdataset('../Processed-Data/HPa_03_04.nc', group='replicate/swr_stats')
blah.to_dataframe()
# Out:
#                                               area  csi  meanrate neuron_id  \
# animal day epoch neuron_number tetrode_number
# HPa    1   1     1             1                    NaN       NaN
#                                2                    NaN       NaN
#                                3                    NaN       NaN
#                                4                    NaN       NaN
#                                5                    NaN       NaN
#                                6                    NaN       NaN
#                                7                    NaN       NaN
#                                8                    NaN       NaN
#                                9                    NaN       NaN
#                                10                   NaN       NaN
#                                11                   NaN       NaN
#                                12                   NaN       NaN
#                                14                   NaN       NaN
#                                15                   NaN       NaN
#                                16                   NaN       NaN
#                                17                   NaN       NaN
#                                18                   NaN       NaN
#                                20                   NaN       NaN
#                  2             1                    NaN       NaN
#                                2                    NaN       NaN
#                                3                    NaN       NaN
#                                4                    NaN       NaN
#                                5                    NaN       NaN
#                                6                    NaN       NaN
#                                7                    NaN       NaN
#                                8                    NaN       NaN
#                                9                    NaN       NaN
#                                10                   NaN       NaN
#                                11                   NaN       NaN
#                                12                   NaN       NaN
# ...                                            ...  ...       ...       ...
# HPc    8   7     18            7                    NaN       NaN
#                                8                    NaN       NaN
#                                9                    NaN       NaN
#                                10                   NaN       NaN
#                                11                   NaN       NaN
#                                12                   NaN       NaN
#                                14                   NaN       NaN
#                                15                   NaN       NaN
#                                16                   NaN       NaN
#                                17                   NaN       NaN
#                                18                   NaN       NaN
#                                20                   NaN       NaN
#                  19            1                    NaN       NaN
#                                2                    NaN       NaN
#                                3                    NaN       NaN
#                                4                    NaN       NaN
#                                5                    NaN       NaN
#                                6                    NaN       NaN
#                                7                    NaN       NaN
#                                8                    NaN       NaN
#                                9                    NaN       NaN
#                                10                   NaN       NaN
#                                11                   NaN       NaN
#                                12                   NaN       NaN
#                                14                   NaN       NaN
#                                15                   NaN       NaN
#                                16                   NaN       NaN
#                                17                   NaN       NaN
#                                18                   NaN       NaN
#                                20                   NaN       NaN
#
#                                                numspikes  propbursts  \
# animal day epoch neuron_number tetrode_number
# HPa    1   1     1             1                     NaN         NaN
#                                2                     NaN         NaN
#                                3                     NaN         NaN
#                                4                     NaN         NaN
#                                5                     NaN         NaN
#                                6                     NaN         NaN
#                                7                     NaN         NaN
#                                8                     NaN         NaN
#                                9                     NaN         NaN
#                                10                    NaN         NaN
#                                11                    NaN         NaN
#                                12                    NaN         NaN
#                                14                    NaN         NaN
#                                15                    NaN         NaN
#                                16                    NaN         NaN
#                                17                    NaN         NaN
#                                18                    NaN         NaN
#                                20                    NaN         NaN
#                  2             1                     NaN         NaN
#                                2                     NaN         NaN
#                                3                     NaN         NaN
#                                4                     NaN         NaN
#                                5                     NaN         NaN
#                                6                     NaN         NaN
#                                7                     NaN         NaN
#                                8                     NaN         NaN
#                                                peak_time  trough_time
# animal day epoch neuron_number tetrode_number
# HPa    1   1     1             1                     NaN          NaN
#                                2                     NaN          NaN
#                                3                     NaN          NaN
#                                4                     NaN          NaN
#                                5                     NaN          NaN
#                                6                     NaN          NaN
#                                7                     NaN          NaN
#                                8                     NaN          NaN
#                                9                     NaN          NaN
#                                10                    NaN          NaN
#                                11                    NaN          NaN
#                                12                    NaN          NaN
#                                14                    NaN          NaN
#                                15                    NaN          NaN
#                                16                    NaN          NaN
#                                17                    NaN          NaN
#                                18                    NaN          NaN
#                                20                    NaN          NaN
#                  2             1                     NaN          NaN
#                                2                     NaN          NaN
#                                3                     NaN          NaN
#                                4                     NaN          NaN
#                                5                     NaN          NaN
#                                6                     NaN          NaN
#                                7                     NaN          NaN
#                                8                     NaN          NaN
#                                9                     NaN          NaN
#                                10                    NaN          NaN
#                                11                    NaN          NaN
#                                12                    NaN          NaN
# ...                                                  ...          ...
# HPc    8   7     18            7                     NaN          NaN
#                                8                     NaN          NaN
#                                9                     NaN          NaN
#                                10                    NaN          NaN
#                                11                    NaN          NaN
#                                12                    NaN          NaN
#                                14                    NaN          NaN
#                                15                    NaN          NaN
#                                16                    NaN          NaN
#                                17                    NaN          NaN
#                                18                    NaN          NaN
#                                20                    NaN          NaN
#                  19            1                     NaN          NaN
#                                2                     NaN          NaN
#                                3                     NaN          NaN
#                                4                     NaN          NaN
#                                5                     NaN          NaN
#                                6                     NaN          NaN
#                                7                     NaN          NaN
#                                8                     NaN          NaN
#                                9                     NaN          NaN
#                                10                    NaN          NaN
#                                11                    NaN          NaN
#                                12                    NaN          NaN
#                                14                    NaN          NaN
#                                15                    NaN          NaN
#                                16                    NaN          NaN
#                                17                    NaN          NaN
#                                18                    NaN          NaN
#                                20                    NaN          NaN
#
# [57456 rows x 13 columns]

# %%
blah = xr.open_mfdataset('../Processed-Data/*.nc', group='replicate/swr_stats',
                         concat_dim=['blah'])
blah
# Out:
# -------------------------------------------------
# ValueError      Traceback (most recent call last)
# <ipython-input-3-6e73cbf3f788> in <module>()
#       1 blah = xr.open_mfdataset('../Processed-Data/*.nc', group='replicate/swr_stats',
# ----> 2                          concat_dim=['blah'])
#       3 blah
#
# /projectnb/braincom/edeno/conda_envs/Jadhav-2016-Data-Analysis/lib/python3.6/site-packages/xarray/backends/api.py in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, lock, data_vars, coords, autoclose, parallel, **kwargs)
#     640             combined = auto_combine(datasets, concat_dim=concat_dim,
#     641                                     compat=compat,
# --> 642                                     data_vars=data_vars, coords=coords)
#     643     except ValueError:
#     644         for ds in datasets:
#
# /projectnb/braincom/edeno/conda_envs/Jadhav-2016-Data-Analysis/lib/python3.6/site-packages/xarray/core/combine.py in auto_combine(datasets, concat_dim, compat, data_vars, coords)
#     434         concatenated = [_auto_concat(ds, dim=dim,
#     435                                      data_vars=data_vars, coords=coords)
# --> 436                         for ds in grouped]
#     437     else:
#     438         concatenated = datasets
#
# /projectnb/braincom/edeno/conda_envs/Jadhav-2016-Data-Analysis/lib/python3.6/site-packages/xarray/core/combine.py in <listcomp>(.0)
#     434         concatenated = [_auto_concat(ds, dim=dim,
#     435                                      data_vars=data_vars, coords=coords)
# --> 436                         for ds in grouped]
#     437     else:
#     438         concatenated = datasets
#
# /projectnb/braincom/edeno/conda_envs/Jadhav-2016-Data-Analysis/lib/python3.6/site-packages/xarray/core/combine.py in _auto_concat(datasets, dim, data_vars, coords)
#     363                                  'explicitly')
#     364             dim, = concat_dims
# --> 365         return concat(datasets, dim=dim, data_vars=data_vars, coords=coords)
#     366
#     367
#
# /projectnb/braincom/edeno/conda_envs/Jadhav-2016-Data-Analysis/lib/python3.6/site-packages/xarray/core/combine.py in concat(objs, dim, data_vars, coords, compat, positions, indexers, mode, concat_over)
#     118         raise TypeError('can only concatenate xarray Dataset and DataArray '
#     119                         'objects, got %s' % type(first_obj))
# --> 120     return f(objs, dim, data_vars, coords, compat, positions)
#     121
#     122
#
# /projectnb/braincom/edeno/conda_envs/Jadhav-2016-Data-Analysis/lib/python3.6/site-packages/xarray/core/combine.py in _dataset_concat(datasets, dim, data_vars, coords, compat, positions)
#     311     if coord is not None:
#     312         # add concat dimension last to ensure that its in the final Dataset
# --> 313         result[coord.name] = coord
#     314
#     315     return result
#
# /projectnb/braincom/edeno/conda_envs/Jadhav-2016-Data-Analysis/lib/python3.6/site-packages/xarray/core/dataset.py in __setitem__(self, key, value)
#     897                                       'to set Dataset values')
#     898
# --> 899         self.update({key: value})
#     900
#     901     def __delitem__(self, key):
#
# /projectnb/braincom/edeno/conda_envs/Jadhav-2016-Data-Analysis/lib/python3.6/site-packages/xarray/core/dataset.py in update(self, other, inplace)
#    2216             dataset.
#    2217         """
# -> 2218         variables, coord_names, dims = dataset_update_method(self, other)
#    2219
#    2220         return self._replace_vars_and_dims(variables, coord_names, dims,
#
# /projectnb/braincom/edeno/conda_envs/Jadhav-2016-Data-Analysis/lib/python3.6/site-packages/xarray/core/merge.py in dataset_update_method(dataset, other)
#     578
#     579     return merge_core([dataset, other], priority_arg=1,
# --> 580                       indexes=dataset.indexes)
#
# /projectnb/braincom/edeno/conda_envs/Jadhav-2016-Data-Analysis/lib/python3.6/site-packages/xarray/core/merge.py in merge_core(objs, compat, join, priority_arg, explicit_coords, indexes)
#     441     assert_unique_multiindex_level_names(variables)
#     442
# --> 443     dims = calculate_dimensions(variables)
#     444
#     445     if explicit_coords is not None:
#
# /projectnb/braincom/edeno/conda_envs/Jadhav-2016-Data-Analysis/lib/python3.6/site-packages/xarray/core/dataset.py in calculate_dimensions(variables)
#     107                 raise ValueError('conflicting sizes for dimension %r: '
#     108                                  'length %s on %r and length %s on %r' %
# --> 109                                  (dim, size, k, dims[dim], last_used[dim]))
#     110     return dims
#     111
#
# ValueError: conflicting sizes for dimension 'concat_dim': length 1 on 'concat_dim' and length 48 on 'area'
